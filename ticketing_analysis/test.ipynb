# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="your_password",
    database="your_db"
)

cursor = conn.cursor()

# Execute stored procedure
cursor.callproc('ccaas_get_businessHolidays', (param1, param2))

# Fetch results
for result in cursor.stored_results():
    rows = result.fetchall()
    for row in rows:
        print(  )

cursor.close()
conn.close()
